# %%
import re 
import pandas as pd
import nltk

# %% [markdown]
# # Loading the training dataset

# %%
comments =pd.read_csv('comments.csv')

# %%
comments.head(20)
# Out:
#                                                 Reply  Upvote  \
# 0   Brilliant.\r\n\r\nEdit: \r\n\r\nWell, as I’m h...    4543
# 1   Awesome, except all the other coins fell in af...     744
# 2                                  Best Simpsons ever     858
# 3                   Simpsons predicted Bitcoin, again     369
# 4   The things that fall on Homers head are 1) Alt...     971
# 5           Remember Bitcoin? It’s back! In POG form!     139
# 6                                       This is gold.     117
# 7   proof that /r/HighQualityGifs  could be funny ...    1826
# 8   Is this why my friends on social media stopped...      33
# 9                           Bitconeeeeeeeeeeeeeeeect👍      27
# 10  The only inaccurate part is the alts at the to...      17
# 11                      Top Quality shit post. UPVOTE     167
# 12  One of my favourite episodes!! This one and [t...      33
# 13                                    needs "D'hodl!"      15
# 14                         What is dead may never die      41
# 15            The memes are getting better & better.       50
# 16  I didn’t sell at 20k because it’s gonna hit 10...      83
# 17  I can’t believe BTC investors are so annoyed t...      33
# 18                                   WTF is a hodler       76
# 19  So guessing this is true ? Will this affect th...       7
#
#                    Time  Key
# 0   2018-02-04 15:49:03    1
# 1   2018-02-04 17:17:05    1
# 2   2018-02-04 16:05:41    1
# 3   2018-02-04 16:42:58    1
# 4   2018-02-04 17:39:30    1
# 5   2018-02-04 19:01:52    1
# 6   2018-02-04 16:31:44    1
# 7   2018-02-04 18:14:30    1
# 8   2018-02-04 21:14:00    1
# 9   2018-02-04 18:53:36    1
# 10  2018-02-04 18:47:40    1
# 11  2018-02-04 16:37:29    1
# 12  2018-02-04 17:25:29    1
# 13  2018-02-04 19:00:06    1
# 14  2018-02-04 17:50:46    1
# 15  2018-02-04 16:33:08    1
# 16  2018-02-04 18:23:54    1
# 17  2018-02-04 19:01:25    1
# 18  2018-02-04 18:06:56    1
# 19  2018-02-04 18:39:01    1

# %%
comments = comments.drop('Key', axis = 1)

# %%
comments = comments.drop('Time', axis = 1)

# %%
comments.shape
# Out:
# (33101, 2)

# %%
comments.dtypes
# Out:
# Reply     object
# Upvote     int64
# dtype: object

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ### 1. Droping null texts

# %%
comments.dropna(subset=['Reply'], inplace=True)

# %% [markdown]
# ### 2. Removing punctuations and symbols

# %%
comments.Reply = comments.Reply.apply(lambda x: re.sub(r'[^\w\s]', '', x) )

# %% [markdown]
# ### 3. Removing stopwords

# %%
from nltk.corpus import stopwords
stopwords = stopwords.words('english')
comments.Reply = comments.Reply.apply(lambda x: ' '.join([word for word in nltk.word_tokenize(x) if word.lower() not in stopwords]))

# %% [markdown]
# ### 4. Removing links

# %%
comments.Reply = comments.Reply.apply(lambda x: re.sub(r'\(?http\S+', '', x))

# %% [markdown]
# ### 5. Lemmatization and Tokenizing

# %%
from nltk.stem import PorterStemmer
porter_stemmer = PorterStemmer

lemmatizer = nltk.WordNetLemmatizer()
comments.Reply = comments.Reply.apply(lambda x: ' '.join([lemmatizer.lemmatize(word) for word in nltk.word_tokenize(x)]))

# %%
comments.dropna(subset=['Reply'], inplace=True)
comments = comments[comments.Reply != '']

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# ### 1. Wordcloud

# %%
import wordcloud
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

word_str = comments.iloc[:,:].Reply.str.cat(sep='. ')
# Out:
# Bad key "text.kerning_factor" on line 4 in
# D:\Users\micha\anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution

# %%
import random
def grey_color_func(word, font_size, position, orientation, random_state=None, **kwargs):
    return "hsl(0, 0%%, %d%%)" % random.randint(1, 20)

# %%
stp = STOPWORDS.copy()
stp.update([('bitcoin'),('BTC'),('crypto'),('currency')])
wc = WordCloud(background_color="white", max_words=100,  stopwords=stp, collocations=False)
# generate word cloud
wc.generate(word_str)

plt.figure(figsize=(10,20))
plt.imshow(wc.recolor(color_func=grey_color_func, random_state=3))
plt.show()

# %% [markdown]
# # Sentiment Analysis

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB, GaussianNB
from sklearn import metrics
import numpy as np

# %% [markdown]
# ## Prebuilt models

# %% [markdown]
# ### 1. Vader

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer, VaderConstants

# First, initialize VADER
vsid = SentimentIntensityAnalyzer()

# %%
comments.head()
# Out:
#                                                Reply  Upvote
# 0  Brilliant Edit Well Im may well make comment u...    4543
# 1                      Awesome except coin fell lmao     744
# 2                                 Best Simpsons ever     858
# 3                         Simpsons predicted Bitcoin     369
# 4  thing fall Homers head 1 Altcoin boom 2 Fake g...     971

# %%
import copy
vaderOut = copy.deepcopy(comments)

# The output of the vader model is a dictionary so we just need to call .Series() function
vaderOut[['Negative', 'Neutral', 'Positive', 'Compound']] = vaderOut.Reply.apply(lambda x: pd.Series(vsid.polarity_scores(x)))

# %%
comments.head()
# Out:
#                                                Reply  Upvote
# 0  Brilliant Edit Well Im may well make comment u...    4543
# 1                      Awesome except coin fell lmao     744
# 2                                 Best Simpsons ever     858
# 3                         Simpsons predicted Bitcoin     369
# 4  thing fall Homers head 1 Altcoin boom 2 Fake g...     971

# %%
vaderOut.head(20)
# Out:
#                                                 Reply  Upvote  Negative  \
# 0   Brilliant Edit Well Im may well make comment u...    4543     0.000
# 1                       Awesome except coin fell lmao     744     0.000
# 2                                  Best Simpsons ever     858     0.000
# 3                          Simpsons predicted Bitcoin     369     0.000
# 4   thing fall Homers head 1 Altcoin boom 2 Fake g...     971     0.279
# 5                      Remember Bitcoin back POG form     139     0.000
# 6                                                gold     117     0.000
# 7   proof rHighQualityGifs could funny interesting...    1826     0.000
# 8    friend social medium stopped posting crypto gain      33     0.152
# 9                            Bitconeeeeeeeeeeeeeeeect      27     0.000
# 10  inaccurate part alt top cliff watching fall al...      17     0.000
# 11                       Top Quality shit post UPVOTE     167     0.429
# 12  One favourite episode one April fool one Bart ...      33     0.278
# 13                                         need Dhodl      15     0.000
# 14                                 dead may never die      41     0.455
# 15                         meme getting better better      50     0.000
# 16                didnt sell 20k gon na hit 100k 2019      83     0.000
# 17  cant believe BTC investor annoyed people would...      33     0.139
# 18                                         WTF hodler      76     0.819
# 19                     guessing true affect gpu price       7     0.000
#
#     Neutral  Positive  Compound
# 0     0.653     0.347    0.9260
# 1     0.273     0.727    0.8402
# 2     0.323     0.677    0.6369
# 3     1.000     0.000    0.0000
# 4     0.721     0.000   -0.4767
# 5     1.000     0.000    0.0000
# 6     1.000     0.000    0.0000
# 7     0.517     0.483    0.6808
# 8     0.320     0.528    0.6908
# 9     1.000     0.000    0.0000
# 10    0.833     0.167    0.2023
# 11    0.357     0.214   -0.4215
# 12    0.598     0.124   -0.5574
# 13    1.000     0.000    0.0000
# 14    0.212     0.333   -0.2856
# 15    0.256     0.744    0.7003
# 16    1.000     0.000    0.0000
# 17    0.605     0.257    0.5719
# 18    0.181     0.000   -0.6739
# 19    0.588     0.412    0.4215

# %% [markdown]
# ### 2. Textblob

# %%
from textblob.sentiments import NaiveBayesAnalyzer, PatternAnalyzer
from textblob import Blobber

# Initialize prebuilt model
tba = Blobber(analyzer=NaiveBayesAnalyzer())

# %%
textBlobOut = copy.deepcopy(comments)

# The output of this model is not a dictionary but a 
textBlobOut[['Classification', 'Positive', 'Negative']] = textBlobOut.Reply.apply(lambda x: pd.Series({'Classification':tba(x).sentiment[0],
                                                                                                      'Positiove':tba(x).sentiment[1],
                                                                                                      'Negative':tba(x).sentiment[2]}))

# %%
textBlobOut.head(20)
# Out:
#                                                 Reply  Upvote Negative  \
# 0   Brilliant Edit Well Im may well make comment u...    4543      pos
# 1                       Awesome except coin fell lmao     744      pos
# 2                                  Best Simpsons ever     858      pos
# 3                          Simpsons predicted Bitcoin     369      pos
# 4   thing fall Homers head 1 Altcoin boom 2 Fake g...     971      pos
# 5                      Remember Bitcoin back POG form     139      pos
# 6                                                gold     117      pos
# 7   proof rHighQualityGifs could funny interesting...    1826      neg
# 8    friend social medium stopped posting crypto gain      33      neg
# 9                            Bitconeeeeeeeeeeeeeeeect      27      pos
# 10  inaccurate part alt top cliff watching fall al...      17      neg
# 11                       Top Quality shit post UPVOTE     167      pos
# 12  One favourite episode one April fool one Bart ...      33      pos
# 13                                         need Dhodl      15      neg
# 14                                 dead may never die      41      pos
# 15                         meme getting better better      50      neg
# 16                didnt sell 20k gon na hit 100k 2019      83      pos
# 17  cant believe BTC investor annoyed people would...      33      neg
# 18                                         WTF hodler      76      pos
# 19                     guessing true affect gpu price       7      pos
#
#     Positive  Classification
# 0   0.843983        0.156017
# 1   0.684644        0.315356
# 2   0.869844        0.130156
# 3   0.902778        0.097222
# 4   0.508744        0.491256
# 5   0.631358        0.368642
# 6   0.507576        0.492424
# 7   0.440270        0.559730
# 8   0.321189        0.678811
# 9   0.500000        0.500000
# 10  0.158891        0.841109
# 11  0.574206        0.425794
# 12  0.743381        0.256619
# 13  0.466292        0.533708
# 14  0.523958        0.476042
# 15  0.445166        0.554834
# 16  0.772508        0.227492
# 17  0.181149        0.818851
# 18  0.500000        0.500000
# 19  0.806151        0.193849
